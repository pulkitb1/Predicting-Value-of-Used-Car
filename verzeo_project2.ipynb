# %%
from IPython.display import Markdown, display
def printmd(string):
    display(Markdown(string))
printmd('**Training Data Set**')
# Out:
# **Training Data Set**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_excel(r'C:\Users\Pulkit-PC\Desktop\verzeo_project\Data_Train.xlsx')  #importing the csv file from the repective directory

# %%
df.columns
# Out:
# Index(['Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#        'New_Price', 'Price'],
#       dtype='object')

# %%
def printmd(string):
    display(Markdown(string))
printmd('**Filling all the Null Values of New Price with 0**')
# Out:
# **Filling all the Null Values of New Price with 0**

# %%
df['New_Price'] = df['New_Price'].fillna('0')
df
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
# ...

# %%
def printmd(string):
    display(Markdown(string))
printmd('**Dropping all NULL Values**')
# Out:
# **Dropping all NULL Values**

# %%
#print(df.dtypes)
cdf=df.dropna()
cdf
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
# ...

# %%
temp=cdf.copy()

# %%
def printmd(string):
    display(Markdown(string))
printmd('**Changing the data type of Engine to int**')
# Out:
# **Changing the data type of Engine to int**

# %%
temp['Engine'] = temp['Engine'].str.replace('CC', '')
temp['Engine']=temp['Engine'].astype('int')

# %%
cdf=temp.copy()

# %%
def printmd(string):
    display(Markdown(string))
printmd('**Changing the data type of Mileage to float**')
# Out:
# **Changing the data type of Mileage to float**

# %%
temp['Mileage'] = temp['Mileage'].str.replace('kmpl', '')
temp['Mileage'] = temp['Mileage'].str.replace('km/kg', '')
temp['Mileage']=temp['Mileage'].astype('float')

# %%
cdf=temp.copy()

# %%
def printmd(string):
    display(Markdown(string))
printmd('**Changing the data type of Transmission to int**')
# Out:
# **Changing the data type of Transmission to int**

# %%
temp['Transmission'] = temp['Transmission'].str.replace('Manual', '1')
temp['Transmission'] = temp['Transmission'].str.replace('Automatic', '2')
temp['Transmission']=temp['Transmission'].astype('int')

# %%
cdf=temp.copy()
temp=cdf.copy()

# %%
l=temp.Owner_Type.unique()
print(l)
j=1
for i in l:
    k=str(j)
    temp['Owner_Type'] = temp['Owner_Type'].str.replace(i,k)
    print ( i , ":", j)
    j+=1
temp['Owner_Type']=temp['Owner_Type'].astype('int')
# Out:
# ['First' 'Second' 'Fourth & Above' 'Third']
# First : 1
# Second : 2
# Fourth & Above : 3
# Third : 4

# %%
cdf=temp.copy()
cdf
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
# ...

# %%
l=temp.Fuel_Type.unique()
print(l)
j=1
for i in l:
    k=str(j)
    temp['Fuel_Type'] = temp['Fuel_Type'].str.replace(i,k)
    print ( i , ":", j)
    j+=1
temp['Fuel_Type']=temp['Fuel_Type'].astype('int')    
print(temp.dtypes)
cdf=temp.copy()
# Out:
# ['CNG' 'Diesel' 'Petrol' 'LPG']
# CNG : 1
# Diesel : 2
# Petrol : 3
# LPG : 4
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type              int32
# Transmission           int32
# Owner_Type             int32
# Mileage              float64
# Engine                 int32
# Power                 object
# Seats                float64
# New_Price             object
# Price                float64
# dtype: object

# %%
def printmd(string):
    display(Markdown(string))
printmd('**Changing the data type of Power to float**')
# Out:
# **Changing the data type of Power to float**

# %%
temp['Power'] = temp['Power'].str.replace('bhp', '')
temp['Power'] = temp['Power'].str.replace('null', '0')
temp['Power']=temp['Power'].astype('float')

# %%
cdf=temp.copy()

# %%
def printmd(string):
    display(Markdown(string))
printmd('**Changing the data type of New Price to float**')
# Out:
# **Changing the data type of New Price to float**

# %%
temp['New_Price'] = temp['New_Price'].str.replace('Lakh', '')
temp['New_Price']=temp['New_Price'].astype('str') 
l=temp['New_Price'].tolist()
count=0
for i in l:
    #print((i))  
    p=i.count('Cr')
    if p>0:
        i=i.replace('Cr','')
        i=float(i) 
        i=i*100
        i=str(i)
        temp.iloc[count,11]=i
    count+=1
temp['New_Price']=temp['New_Price'].astype('float')

# %%
cdf=temp.copy()

# %%
l=temp.Location.unique()
j=1
for i in l:
    k=str(j)
    temp['Location'] = temp['Location'].str.replace(i,k)
    print ( i , ":", j)
    j+=1
temp['Location']=temp['Location'].astype('int')
# Out:
# Mumbai : 1
# Pune : 2
# Chennai : 3
# Coimbatore : 4
# Hyderabad : 5
# Jaipur : 6
# Kochi : 7
# Kolkata : 8
# Delhi : 9
# Bangalore : 10
# Ahmedabad : 11

# %%
cdf=temp.copy()

# %%
def printmd(string):
    display(Markdown(string))
printmd('**Training Data Set after EDA**')
# Out:
# **Training Data Set after EDA**

# %%
temp
# Out:
#                                   Name  Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG         1  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option         2  2015              41000
# 2                         Honda Jazz V         3  2011              46000
# 3                    Maruti Ertiga VDI         3  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic         4  2013              40670
# ...                                ...       ...   ...                ...
# 6014                  Maruti Swift VDI         9  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S         6  2015             100000
# 6016             Mahindra Xylo D4 BSIV         6  2012              55000
# 6017                Maruti Wagon R VXI         8  2013              46000
# 6018             Chevrolet Beat Diesel         5  2011              47000
#
#       Fuel_Type  Transmission  Owner_Type  Mileage  Engine   Power  Seats  \
# ...

# %%
print(temp.dtypes)
# Out:
# Name                  object
# Location               int32
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type              int32
# Transmission           int32
# Owner_Type             int32
# Mileage              float64
# Engine                 int32
# Power                float64
# Seats                float64
# New_Price            float64
# Price                float64
# dtype: object

# %%
sns.pairplot(cdf,hue='Location')
# Out:
# C:\Users\Pulkit-PC\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\Pulkit-PC\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
from pandas import DataFrame
import matplotlib.pyplot as plt

for i in temp.columns:
    
    if (i!='Price') and (i!='Name'):
        plt.scatter(temp['Price'], temp[i], color='red')
        ti='Price Vs ' + i
        plt.title(ti, fontsize=14)
        plt.xlabel('Price', fontsize=14)
        plt.ylabel(i, fontsize=14)
        plt.grid(True)
        plt.show()

# %%
def printmd(string):
    display(Markdown(string))
printmd('**Testing Data Set after EDA**')
# Out:
# **Testing Data Set after EDA**

# %%
df2 = pd.read_excel(r'C:\Users\Pulkit-PC\Desktop\verzeo_project\Data_Test.xlsx')
df2['New_Price'] = df2['New_Price'].fillna('0')
cdf2=df2.dropna()
temp2=cdf2.copy()
temp2['Engine'] = temp2['Engine'].str.replace('CC', '')
temp2['Engine']=temp2['Engine'].astype('int')
cdf2=temp2.copy()
temp2['Mileage'] = temp2['Mileage'].str.replace('kmpl', '')
temp2['Mileage'] = temp2['Mileage'].str.replace('km/kg', '')
temp2['Mileage']=temp2['Mileage'].astype('float')
cdf2=temp2.copy()
temp2['Transmission'] = temp2['Transmission'].str.replace('Manual', '1')
temp2['Transmission'] = temp2['Transmission'].str.replace('Automatic', '2')
temp2['Transmission']=temp2['Transmission'].astype('int')
cdf2=temp2.copy()
temp2=cdf2.copy()
l=temp2.Owner_Type.unique()
j=1
for i in l:
    k=str(j)
    temp2['Owner_Type'] = temp2['Owner_Type'].str.replace(i,k)
    #print ( i , ":", j)
    j+=1
temp2['Owner_Type']=temp2['Owner_Type'].astype('int')    
cdf2=temp2.copy()
l=temp2.Fuel_Type.unique()
j=1
for i in l:
    k=str(j)
    temp2['Fuel_Type'] = temp2['Fuel_Type'].str.replace(i,k)
    #print ( i , ":", j)
    j+=1
temp2['Fuel_Type']=temp2['Fuel_Type'].astype('int')    
cdf2=temp2.copy()
temp2['Power'] = temp2['Power'].str.replace('bhp', '')
temp2['Power'] = temp2['Power'].str.replace('null', '0')
temp2['Power']=temp2['Power'].astype('float')
cdf2=temp2.copy()
temp2['New_Price'] = temp2['New_Price'].str.replace('Lakh', '')
temp2['New_Price']=temp2['New_Price'].astype('str') 
l=temp2['New_Price'].tolist()
count=0
for i in l:
    #print((i))  
    p=i.count('Cr')
    if p>0:
        i=i.replace('Cr','')
        i=float(i) 
        i=i*100
        i=str(i)
        temp2.iloc[count,11]=i
    count+=1
temp2['New_Price']=temp2['New_Price'].astype('float')
cdf2=temp2.copy()
l=temp2.Location.unique()
j=1
for i in l:
    k=str(j)
    temp2['Location'] = temp2['Location'].str.replace(i,k)
    #print ( i , ":", j)
    j+=1
temp2['Location']=temp2['Location'].astype('int')    
cdf2=temp2.copy()

# %%
def printmd(string):
    display(Markdown(string))
printmd('**Applying Multi Variate Linear Regression**')
# Out:
# **Applying Multi Variate Linear Regression**

# %%
from pandas import DataFrame
from sklearn import linear_model
import statsmodels.api as sm  
from sklearn.metrics import mean_squared_error, r2_score

X = temp[['Year','Engine','Power','Kilometers_Driven','Fuel_Type','Owner_Type','Transmission','New_Price','Seats','Mileage','Location']] # here we have 2 variables for multiple regression. If you just want to use one variable for simple linear regression, then use X = df['Interest_Rate'] for example.Alternatively, you may add additional variables within the brackets
Y = temp['Price']
 
# with sklearn
regr = linear_model.LinearRegression()
regr.fit(X, Y)

#print('Intercept: \n', regr.intercept_)
#print('Coefficients: \n', regr.coef_)

count=0
count2=0
for index, row in temp.iterrows():
    New_Year = row['Year']
    New_Power = row['Power']
    New_Engine = row['Engine']
    New_New_Price = row['New_Price']
    New_km=row['Kilometers_Driven']
    New_owner=row['Owner_Type']
    New_fuel=row['Fuel_Type']
    New_mileage=row['Mileage']
    New_seats=row['Seats']
    New_transmission=row['Transmission']
    New_location=row['Location']
    p=regr.predict([[New_Year,New_Engine,New_Power,New_km,New_fuel,New_owner,New_transmission,New_New_Price,New_seats,New_mileage,New_location]])
    #print ('Predicted Price:', p[0] , ' Actual Price : ',row['Price'])

Y1=regr.predict(X)    
rmse = mean_squared_error(Y,Y1)
r2 = r2_score(Y, Y1)
print('Variance score: %.2f' % regr.score(X, Y))
print('R2 score: ', r2)

predicted_price={}

for index, row in temp2.iterrows():
    New_Year = row['Year']
    New_Power = row['Power']
    New_Engine = row['Engine']
    New_km=row['Kilometers_Driven']
    New_owner=row['Owner_Type']
    New_fuel=row['Fuel_Type']
    New_mileage=row['Mileage']
    New_seats=row['Seats']
    New_transmission=row['Transmission']
    New_location=row['Location']
    p=regr.predict([[New_Year,New_Engine,New_Power,New_km,New_fuel,New_owner,New_transmission,New_New_Price,New_seats,New_mileage,New_location]])
    predicted_price[index]=p[0]
# Out:
# Variance score: 0.71
# R2 score:  0.7107561047269604

# %%
def printmd(string):
    display(Markdown(string))
printmd('**The Predicted Values for Test Data are -**')
# Out:
# **The Predicted Values for Test Data are -**

# %%
predicted_price
# Out:
# {0: 3.854399450331357,
#  1: -0.5354846202155841,
#  2: 13.875489482524017,
#  3: -5.145024288206059,
#  4: 6.476294406832267,
#  5: 10.936841478169754,
#  6: 18.915721374869236,
#  7: 1.3516070979144388,
#  8: 8.001311871601274,
#  9: 10.199416013363361,
#  10: 16.06426914720646,
#  11: 8.221116509255125,
#  12: 7.127696251072848,
#  13: -1.8058285180377425,
#  14: 11.094508508609806,
#  15: 16.901973456256883,
#  16: 18.04221558608583,
#  17: 0.5827451832360566,
#  18: 12.86850279593068,
#  19: 8.397285526193173,
#  20: 4.178934435789415,
#  21: 2.269302832253743,
#  22: 3.3031983753412533,
#  24: 10.721164217472733,
#  25: -1.032034772152656,
#  26: -5.485945318073618,
#  27: 4.505078855891725,
#  28: 9.388618437372998,
#  29: 4.105324068874324,
#  30: 1.92354585979092,
#  31: 8.169153307516353,
#  32: 0.9110228363872466,
#  33: 10.665837504364617,
#  34: 3.148893090871752,
#  35: 7.583698194076078,
#  36: 16.221143282969933,
#  37: 13.849437767981499,
#  38: 2.655697006363198,
# ...
